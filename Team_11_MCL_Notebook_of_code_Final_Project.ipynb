# %% [markdown]
# <a href="https://colab.research.google.com/github/Mboni777/Projects/blob/main/Team_11_MCL_Notebook_of_code_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Processing with Linear Algebra and Multivariable Calculus  Project code notebook
#
#
# ---
#
#
#
#
# **Course**: MATH211: Multivariable Calculus & Linear Algebra
#
# **Team Members**: Jason,
#                      Gervais Mboninkunda, and
#                      Kwaku
#
# **University**: Ashesi University
#
# **Semester**: YI, Second Semester Summer 2025
#
# **Project Title**: Application of Multivariable Calculus and Linear Algebra Concepts in Image Processing
#
# **Submittion date**: 20th, Jully 2025

# %% [markdown]
# ## Task 1:  Setting-up Project development emvironement in google colab.

# %% [markdown]
#  we are using google colab which is suitable for team collaboration on one project as our main purpose, and also python is pre-installed in this environment as well as Jupyternotebook development Interface.
#
# Here, we are going install all necessary Python libraries and imported them into our notebook for usage. These libraries will help us process and visualize images, perform matrix operations from Linear Algeabra, and apply multivariable calculus techniques throughout this project.

# %%
# Installing of all possible required libraries for image processing by using linear algeabra and Multivariable calculus

# !pip install  numpy   scipy   sympy   matplotlib  opencv-python   Pillow   scikit-image

# %%
# Importing required modules from pre-installed libraries above
import numpy as np     # for numerical computations
import matplotlib.pyplot as plt # for data visualization
import sympy as sp  # for writting both mathematical symbols and other symbols
import cv2  # This is a module for loading image by using Open cv library
from skimage import io, filters, color, transform  # for image manupulation and processing
from PIL import Image # this is for opening, displayig, croping, or converting image files easily
from sympy import symbols, diff, Matrix, init_printing # This is a python library with functions that allow us to write or define symbols in python programs
from scipy import linalg  # This a scientific python library that gives more advanced mathematical computations  like finding eigen values, differentiation, integration, SDV calculation and others

# %%
from google.colab import drive
drive.mount('/content/drive')
